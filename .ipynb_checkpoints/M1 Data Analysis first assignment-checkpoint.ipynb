# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.array([2010, 2015, 2016, 2017, 2018])
y = np.array([170560182, 189380513, 193203476, 197015955, 200813818])
plt.scatter(x,y, s=500, c='b', marker=r'$\clubsuit$', alpha=0.5)
# plt.scatter?
plt.xlabel('years')
plt.ylabel('polulation')
plt.legend(['A simple Line'], loc="upper left")
plt.show()

# %%
matplotlib.markers?
# Out:
# Object `matplotlib.markers` not found.

# %%
~matplotlib.markers
